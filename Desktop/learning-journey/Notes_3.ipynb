# %%
print("Hello, I am newbie here")

# random.randrange(1, 129)
# list()
# in OR not in => True OR False
# Out:
# Hello, I am newbie here

# %%
''' # Train Example 2 for list
import random

n = int(input("Set of numbers: "))

for x in range (n):
    red = [i for i in range(1, 34)]
    blue = [random.randrange(1,17)]
    B = random.choice(blue)
    R = list(random.sample(red, 6))
    R.sort
    [print(f"\033[31m{x:0>2d}", end = " ") for x in R]
    print(f"\033[34m{B:0>2d}")
    print()
'''

# %%
''' # Throw a dice 6000 times, records the no. of times appear for each point

import random


records = [0, 0, 0, 0, 0, 0] # records = [0] * 6

for i in range(6000):
    x = random.randrange(1, 7)
    records[x - 1] += 1

for j in range(6):
    print(f"Point {j + 1} appear {records[j]} times")
'''

# %%
''' # Function for finding prime numbers in a given range
def judge(n) -> bool:
    for x in range(2, int((n ** 0.5) // 1) + 1):
        if n % x == 0:
            return False
    return True


for i in range(2, 100):
    if judge(i):
        print(i)
'''

''' # Find Prime number in range (1 to 100)
for i in range(2, 101):
    x = i
    n = int(round(i ** 0.5))
    for j in range(2,n + 1):
        if i % j == 0:
            x = 0
            break
    if x != 0:
        print(x)
'''

# %%
''' # Guess a value
import random


n = random.randrange(1, 129)
i = 0
while True:
    Input = int(input("Guess a value: "))
    i += 1
    if Input == n:
        break
    elif Input > n:
        print("The true value is smaller than your guess")
    else:
        print("The true value is bigger than your guess")

if i == 1:
    print(f"You are so lucky!")
elif i <= 6:
    print(f"Congratulation, your number of attempts are {i} times, you are kinda smart")
elif i == 7:
    print(f"Unfortunately, your number of attempts are {i} times, you are kinda unlucky")
else:
    print(f"Finally, you guess correctly. The answer is {n}")
'''

# %%
''' # Sum of 1 - 100, but only odd numbers [print(sum(range(1, 101, 2)))]
sum = 0
for i in range(1, 101, 2):
    sum += i
print(f"The sum of the odd numbers is: {sum}")
'''

''' # Function to find the sum of values
def add(*val):
    x = 0
    for y in val:
      if type(y) in (int, float):
        x += y
    return x

print(add())
'''

# %%
''' # Find value of factorial
def fac(n):
    x = 1
    for y in range(2, n + 1):
        x *= y
    return x

    
print("To find mCn, give integer number for")
m = int(input("Value of m: "))
n = int(input("Value of n: "))
print(f"The value of mCn is {(fac(m) // fac(n)) // fac(m - n)}")
'''

# %%
''' # Train Example 1 for list
import random

l = []
for _ in range (10):
    l.append(random.randrange(1, 100))
print(l)

l = [x for x in l if x % 2 == 0]
print(l)

l = [x ** 0.5 for x in l if x > 50]
print(l)
'''

# %%
''' # Find Narcissistic number in range (100 to 1000)
for i in range(100, 1000):
    x = i % 10
    z = i // 100
    y = (i - (z * 100) - (x)) / 10 # i // 10 % 10
    if (x ** 3) + (y ** 3) + (z ** 3) == i:
        print(i)
'''

# %%
''' # Multiplication table (1 to 12)
for i in range(1, 13):
    for j in range(1, i + 1):
        print(f"{i} * {j} = {i * j} ", end = "\t")
    print()
'''

# %%
''' # Generate A and B subsequently 100 times
import time

for i in range(1, 101):
    if i % 2 == 1:
        print("A")
    else:
        print("B")
    time.sleep(0)
'''
